# %%
import pandas as pd

# %%
cars_data = pd.read_csv("car-sales.csv")
cars_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Cross Tab
pd.crosstab(cars_data["Make"], cars_data["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group by
cars_data.groupby(["Make"]).sum()
# Out:
#                      Colour  Odometer (KM)  Doors  \
# Make
# BMW                   Black          11179      5
# Honda           RedBlueBlue         188335     12
# Nissan           WhiteWhite         244695      8
# Toyota  WhiteBlueGreenWhite         341805     15
#
#                                        Price
# Make
# BMW                               $22,000.00
# Honda            $5,000.00$7,500.00$7,000.00
# Nissan                    $3,500.00$9,700.00
# Toyota  $4,000.00$7,000.00$4,500.00$6,250.00

# %%
cars_data.plot()
# Out:
# <Axes: >

# %%
cars_data["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
# Changing datatype of Price column
cars_data["Price"] = (cars_data["Price"].str.replace(r"[\$,]", "", regex=True).astype(float).astype(int))
cars_data["Price"].dtype
# Out:
# dtype('int64')

# %%
cars_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700
